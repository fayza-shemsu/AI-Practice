# %%
import sys
import os

sys.path.append(os.path.abspath("../../"))

from src.pipelines.train_pipeline import train_pipeline

model = train_pipeline("../../data/raw/Housing.csv")

print("PIPELINE WORKED")
# Out:
# ✅ Data loaded successfully
# PIPELINE WORKED
