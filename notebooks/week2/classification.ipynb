# %%
import sys
import os

sys.path.append(os.path.abspath("../../"))

from src.pipelines.classification_pipeline import run_classification_pipeline

pipeline = run_classification_pipeline("../../data/raw/customer_churn_dataset-testing-master.csv")

print("Classification pipeline working")
# Out:
# ✅ Data loaded successfully
# [1 0]
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64
# 0
# Train Accuracy: 1.0
# Test Accuracy: 0.9984466019417476
# Confusion Matrix:
# [[6741   52]
#  [   0 6082]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      6793
#            1       0.99      1.00      1.00      6082
#
#     accuracy                           1.00     12875
#    macro avg       1.00      1.00      1.00     12875
# weighted avg       1.00      1.00      1.00     12875
#
# Classification pipeline working
