# %%
import sys
# !{sys.executable} -m pip install pandas numpy scikit-learn joblib matplotlib seaborn

# %%
import sys
import os

sys.path.append(os.path.abspath("../../"))

from src.pipelines.classification_pipeline import run_classification_pipeline

pipeline = run_classification_pipeline("../../data/raw/customer_churn_dataset-testing-master.csv")

print("Classification pipeline working")
# Out:
# ✅ Data loaded successfully
# ✅ Data loaded successfully
# [1 0]
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64
# 0
#
# ...
# Train Accuracy: 0.7886
# Test Accuracy : 0.7828
# ...
#
# 🔍 Threshold Analysis:
#
# Threshold: 0.5
# [[4441 2335]
#  [ 462 5637]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.66      0.76      6776
#            1       0.71      0.92      0.80      6099
#
#     accuracy                           0.78     12875
#    macro avg       0.81      0.79      0.78     12875
# weighted avg       0.81      0.78      0.78     12875
#
#
# Threshold: 0.4
# [[4039 2737]
#  [  12 6087]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75      6776
# ...
