# %%
import sys
import os

sys.path.append(os.path.abspath("../../"))

from src.pipelines.model_selection import run_model_selection

results = run_model_selection("../../data/raw/customer_churn_dataset-testing-master.csv")
# Out:
# ✅ Data loaded successfully
# ✅ Data loaded successfully
#
# Missing values:
#  Age                   0
# Gender                0
# Tenure                0
# Usage Frequency       0
# Support Calls         0
# Subscription Type     0
# Contract Length       0
# Total Spend           0
# Last Interaction      0
# Churn                 0
# support_per_tenure    0
# usage_per_tenure      0
# spend_per_month       0
# inactive_score        0
# high_support_flag     0
# low_usage_flag        0
# dtype: int64
#
# ====================
# LogisticRegression
# ====================
# Train Accuracy : 0.6937
# Test Accuracy  : 0.6899
# Best F1 Score  : 0.7171
# ROC-AUC        : 0.7612
# Best Threshold : 0.4
#
# Confusion Matrix:
# [[3822 2954]
#  [1039 5060]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.56      0.66      6776
#            1       0.63      0.83      0.72      6099
#
#     accuracy                           0.69     12875
#    macro avg       0.71      0.70      0.69     12875
# weighted avg       0.71      0.69      0.69     12875
#
#
# ====================
# RandomForest
# ====================
# Train Accuracy : 0.8171
# Test Accuracy  : 0.7866
# Best F1 Score  : 0.8159
# ROC-AUC        : 0.8529
# Best Threshold : 0.4
#
# Confusion Matrix:
# [[4042 2734]
#  [  13 6086]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75      6776
#            1       0.69      1.00      0.82      6099
#
#     accuracy                           0.79     12875
#    macro avg       0.84      0.80      0.78     12875
# weighted avg       0.85      0.79      0.78     12875
#
#
# 🏆 MODEL COMPARISON
# LogisticRegression: F1=0.7171, ROC=0.7612, Threshold=0.4
# RandomForest: F1=0.8159, ROC=0.8529, Threshold=0.4
#
# ✅ Best Model: RandomForest
#
# 💾 Best model + threshold saved successfully
