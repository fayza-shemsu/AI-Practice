# %%
import sys
import os

sys.path.append(os.path.abspath("../../"))


from src.pipelines.model_selection import run_model_selection

results = run_model_selection("../../data/raw/customer_churn_dataset-testing-master.csv")
# Out:
# ✅ Data loaded successfully
#
# LogisticRegression
# Train Accuracy: 0.8252
# Test Accuracy : 0.8317
# F1 Score      : 0.8234
#
# RandomForest
# Train Accuracy: 1.0000
# Test Accuracy : 0.9984
# F1 Score      : 0.9984
#
# SVM
# Train Accuracy: 0.9508
# Test Accuracy : 0.9477
# F1 Score      : 0.9452
#
# 🏆 Leaderboard (by F1-score):
# RandomForest: F1=0.9984, Train=1.0000, Test=0.9984
# SVM: F1=0.9452, Train=0.9508, Test=0.9477
# LogisticRegression: F1=0.8234, Train=0.8252, Test=0.8317
#
# ✅ Best Model: RandomForest with F1 = 0.9984
