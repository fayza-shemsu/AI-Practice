# %%
import sys
import os

sys.path.append(os.path.abspath("../../"))

from src.pipelines.hyperparameter_tuning import tune_random_forest

model = tune_random_forest("../../data/raw/customer_churn_dataset-testing-master.csv")
# Out:
# ✅ Data loaded successfully
# ✅ Data loaded successfully
# 🚫 Removed Payment Delay (to avoid trivial prediction)
#
# 🔍 Correlation Check with Target:
# Churn               1.000000
# Support Calls       0.304631
# Tenure              0.195327
# Age                 0.063457
# Last Interaction   -0.002818
# Total Spend        -0.078867
# Usage Frequency    -0.115098
# Name: Churn, dtype: float64
#
# ✔ No obvious leakage detected
#
# 🔍 Running Grid Search...
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
#
# ✅ Best Parameters:
# {'model__max_depth': 10, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200}
#
# 📊 Confusion Matrix:
# [[4325 2451]
#  [ 285 5814]]
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      6776
#            1       0.70      0.95      0.81      6099
#
#     accuracy                           0.79     12875
# ...
